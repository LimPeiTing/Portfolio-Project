# %% [markdown]
# Dataset from Kaggle (Medical Insurance cost): https://www.kaggle.com/datasets/mirichoi0218/insurance

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\LIM PEI TING\Documents\Machine learning dataset from Kaggle\Medical insurance cost\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Overview of dataset

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='sex', hue='sex', palette = {"male":"orange", "female":"blue"}, legend = True)
plt.title('Sex Count')
plt.xlabel('Sex')
plt.show()

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='region', hue='region', palette= 'bright', legend = True)
plt.title('Region Count')
plt.xlabel('Region')
plt.show()

# %%
df['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
plt.figure(figsize=(6, 6))
sns.countplot(data=df, x='children',hue='children', palette='bright', legend=True)
plt.title('Children Count')
plt.xlabel('Children')
plt.show()

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df, x='smoker', hue='smoker', palette= 'bright', legend = True)
plt.title('Smoker count')
plt.xlabel('Smoker')
plt.show()

# %%
df[df['smoker'] == 'no'].shape[0]
# Out:
# 1064

# %%
sns.set(style = "whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(df['age'], color='green', kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set(style = "whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(df['bmi'], color='orange', kde=True)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set(style = "whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(df['charges'], color='purple', kde=True)
plt.title('Charges Distribution')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Charges vs Smoker status

# %%
sns.barplot(data=df, x='smoker', y='charges', hue='smoker', palette='bright', legend=False)
plt.title('Charges vs Smoker')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# From the graph, can observed smoker pay more for the medical cost when compared with non-smoker

# %% [markdown]
# Charges vs Age by Smoking status

# %%
sns.scatterplot(data=df, x='age', y='charges', hue='smoker', legend=True)
plt.title('Charges vs Age by Smoker status')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# Charges vs Region status

# %%
sns.barplot(data=df, x='region', y='charges', hue='region', palette='bright', legend=False)
plt.title('Charges vs Region')
plt.xlabel('Region')
plt.ylabel('Charges')
plt.show()

# From the graph, can observed southeast region pay the most for the medical cost among the others.

# %% [markdown]
# Charges vs Number of children status

# %%
sns.barplot(data=df, x='children', y='charges', hue='children', palette='bright', legend=False)
plt.title('Charges vs Children')
plt.xlabel('Children')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# Charges vs BMI by Smoking status

# %%
sns.scatterplot(data=df, x='bmi', y='charges', hue='smoker', legend=True)
plt.title('Charges vs BMI by Smoker status')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.show()

# %%
features = ['sex', 'children', 'smoker', 'region']

plt.subplots(1, 4, figsize=(20, 10))
for i, col in enumerate(features):
    plt.subplot(1, 4, i + 1)
    x = df[col].value_counts()
    plt.pie(x.values, labels=x.index, autopct='%1.1f%%')
    plt.title(f'{col} distribution')
    plt.axis('off')  # Turn off axes (removes grid lines and axis labels)
plt.show()

# %%
# enumerate() is a Python built-in function that adds a counter to an iterable (in this case, features)

# %%
features = ['age', 'bmi', 'charges']

plt.figure(figsize=(12, 3))
for i, col in enumerate(features):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(data=df, x=col)
    plt.title(f'{col} distribution')
    
    # Remove the grid and tick marks (without this part, the result will showed uneccessary grid)
    plt.grid(False)  # Turns off the grid
    plt.xticks([])   # Removes x-axis tick marks
    plt.yticks([])   # Removes y-axis tick marks
    plt.xlabel('')   # Removes x-axis label
    plt.ylabel('')   # Removes y-axis label

plt.tight_layout()  # Adjusts subplot spacing
plt.show()

# %%
# From the boxplot, it can observed that bmi has some outliers.

# %%
df.hist(bins = 30, figsize=(10, 6), color = 'blue')
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'children'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='Greens')
plt.title('Correlation Heatmap of Medical Insurance')
plt.show()

# %%
# From the correlation map, it seems like age has slightly stornger linear relationship with charges when compared with bmi and number of children.

# %% [markdown]
# Check for skewness of the dataset

# %% [markdown]
# Skewness is a statistical measure used to describe the shape of a probability distribution.
#
# It measures the asymmetry of a distribution.
#
# Skewness indicates the direction and degree to which the data deviates from a symmetrical bell curve.
#
# A distribution with zero skewness is perfectly symmetrical, meaning the left and right sides of the distribution are mirror images.
#
# Positive skewness or right skewed (skewness > 0) means more weight in the left tail of the distribution, the right tail is longer or fatter than the left, suggesting that the data has a tendency to have higher values.
#
# Negative skewness or left skewed (skewness < 0) means more weight in the right tail of the distribution, the left tail is longer or fatter, implying a tendency towards lower values.
#
# Magnitude of skewness:
#
# (-0.5, 0.5) —— low or approximately symmetric.
#
# Beyond -1 and 1 —— Highly skewed.
#
# else —— moderately skewed.

# %%
from scipy.stats import skew

features = ['age', 'bmi', 'charges']

for col in features:
    s = skew(df[col])
    if s >= -0.5 and s <= 0.5:
        print(f'Skewness of {col} = {s:.4f} [low or approximately symmetric]')
    elif s <= -1:
        print(f'Skewness of {col} = {s:.4f} [highly left skewed]')
    elif s >= 1:
        print(f'Skewness of {col} = {s:.4f} [highly right skewed]')
    else:
        print(f'Skewness of {col} = {s:.4f} [moderately skewed]')
# Out:
# Skewness of age = 0.0556 [low or approximately symmetric]
# Skewness of bmi = 0.2837 [low or approximately symmetric]
# Skewness of charges = 1.5142 [highly right skewed]

# %%
# Skewness of age and bmi are both approximately low, followed the normal distribution, which is ideal for the model's learning

# %% [markdown]
# Data Encoding: categorical data

# %%
df_encoded = df.copy()

df_encoded['sex'] = df_encoded['sex'].map({'female':0,'male':1})
df_encoded['smoker'] = df_encoded['smoker'].map({'yes':1,'no':0})
df_encoded['region'] = df_encoded['region'].map({'southwest':0,'southeast':1,'northwest':2,'northeast':3})

df_encoded.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       0  16884.92400
# 1   18    1  33.770         1       0       1   1725.55230
# 2   28    1  33.000         3       0       1   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %%
df_encoded ['region'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %% [markdown]
# Train / Test Split

# %%
X = df_encoded.drop('charges', axis=1)
y = df_encoded['charges']

# %%
X.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       0
# 1   18    1  33.770         1       0       1
# 2   28    1  33.000         3       0       1
# 3   33    1  22.705         0       0       2
# 4   32    1  28.880         0       0       2

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %% [markdown]
# Data Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 6)
# (268, 6)

# %%
# Since our target variable has continuous value, hence we will be using regression model for the data modelling

# %% [markdown]
# Linear regression

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)

# For regression models, 
lr_r2 = r2_score(y_test, y_pred)
lr_mae = mean_absolute_error(y_test, y_pred)
lr_mse = mean_squared_error(y_test, y_pred)
lr_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
lr_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', lr_r2)
print(f'Mean absolute error (MAE):', lr_mae)
print(f'Mean squared error (MSE):', lr_mse)
print(f'Root-mean squared error (RMSE):', lr_rmse)
print(f'Mean absolute percentage error (MAPE):', lr_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# Decision Tree Regressor

# %%
dt_model = DecisionTreeRegressor(max_depth=5)
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)

# For regression models, 
dt_r2 = r2_score(y_test, y_pred)
dt_mae = mean_absolute_error(y_test, y_pred)
dt_mse = mean_squared_error(y_test, y_pred)
dt_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
dt_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', dt_r2)
print(f'Mean absolute error (MAE):', dt_mae)
print(f'Mean squared error (MSE):', dt_mse)
print(f'Root-mean squared error (RMSE):', dt_rmse)
print(f'Mean absolute percentage error (MAPE):', dt_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# Random Forest Regresssor

# %%
rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# For regression models, 
rf_r2 = r2_score(y_test, y_pred)
rf_mae = mean_absolute_error(y_test, y_pred)
rf_mse = mean_squared_error(y_test, y_pred)
rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rf_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', rf_r2)
print(f'Mean absolute error (MAE):', rf_mae)
print(f'Mean squared error (MSE):', rf_mse)
print(f'Root-mean squared error (RMSE):', rf_rmse)
print(f'Mean absolute percentage error (MAPE):', rf_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# Gradient Boosting Regressor

# %%
gb_model = GradientBoostingRegressor(n_estimators=100)
gb_model.fit(X_train, y_train)
gb_pred = gb_model.predict(X_test)

# For regression models, 
gb_r2 = r2_score(y_test, y_pred)
gb_mae = mean_absolute_error(y_test, y_pred)
gb_mse = mean_squared_error(y_test, y_pred)
gb_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
gb_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', gb_r2)
print(f'Mean absolute error (MAE):', gb_mae)
print(f'Mean squared error (MSE):', gb_mse)
print(f'Root-mean squared error (RMSE):', gb_rmse)
print(f'Mean absolute percentage error (MAPE):', gb_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# Support Vector Regressor

# %%
sv_model = SVR(kernel='rbf')
sv_model.fit(X_train, y_train)
sv_pred = sv_model.predict(X_test)

# For regression models, 
sv_r2 = r2_score(y_test, y_pred)
sv_mae = mean_absolute_error(y_test, y_pred)
sv_mse = mean_squared_error(y_test, y_pred)
sv_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
sv_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', sv_r2)
print(f'Mean absolute error (MAE):', sv_mae)
print(f'Mean squared error (MSE):', sv_mse)
print(f'Root-mean squared error (RMSE):', sv_rmse)
print(f'Mean absolute percentage error (MAPE):', sv_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# K-Neighbors Regressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train, y_train)
knn_pred = knn_model.predict(X_test)

# For regression models, 
knn_r2 = r2_score(y_test, y_pred)
knn_mae = mean_absolute_error(y_test, y_pred)
knn_mse = mean_squared_error(y_test, y_pred)
knn_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
knn_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', knn_r2)
print(f'Mean absolute error (MAE):', knn_mae)
print(f'Mean squared error (MSE):', knn_mse)
print(f'Root-mean squared error (RMSE):', knn_rmse)
print(f'Mean absolute percentage error (MAPE):', knn_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# XGBoost Regressor

# %%
xgb_model = xgb.XGBRegressor(n_estimators=100)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# For regression models, 
xgb_r2 = r2_score(y_test, y_pred)
xgb_mae = mean_absolute_error(y_test, y_pred)
xgb_mse = mean_squared_error(y_test, y_pred)
xgb_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
xgb_mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f'R-square (r2):', xgb_r2)
print(f'Mean absolute error (MAE):', xgb_mae)
print(f'Mean squared error (MSE):', xgb_mse)
print(f'Root-mean squared error (RMSE):', xgb_rmse)
print(f'Mean absolute percentage error (MAPE):', xgb_mape)
# Out:
# R-square (r2): 0.8501724363405039
# Mean absolute error (MAE): 2793.646105652861
# Mean squared error (MSE): 23260539.20063972
# Root-mean squared error (RMSE): 4822.918120872438
# Mean absolute percentage error (MAPE): 0.3677609190204874

# %% [markdown]
# Summarize different regressor r2, MAE, MSE, RSME and MAPE value into a dataframe

# %%
models = ['LinearRegression' , 'Decision Tree' , 'Random Forest', 'Gradient Boosting', 'Support Vector', 'K-Neighbors', 'XGBoost']
data = [[lr_r2, lr_mae, lr_mse, lr_rmse, lr_mape ] , [dt_r2, dt_mae, dt_mse, dt_rmse, dt_mape ] , [rf_r2, rf_mae, rf_mse, rf_rmse, rf_mape ],  [gb_r2, gb_mae, gb_mse, gb_rmse, gb_mape ],  [sv_r2, sv_mae, sv_mse, sv_rmse, sv_mape ], [knn_r2, knn_mae, knn_mse, knn_rmse, knn_mape ], [xgb_r2, xgb_mae, xgb_mse, xgb_rmse, xgb_mape ]]
cols = ["r2_score" , "MAE", "MSE", "RMSE", "MAPE"]
pd.DataFrame(data=data , index= models , columns= cols).sort_values(ascending= True , by = ['r2_score'])
# Out:
#                    r2_score          MAE           MSE         RMSE      MAPE
# LinearRegression   0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# Decision Tree      0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# Random Forest      0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# Gradient Boosting  0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# Support Vector     0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# K-Neighbors        0.850172  2793.646106  2.326054e+07  4822.918121  0.367761
# XGBoost            0.850172  2793.646106  2.326054e+07  4822.918121  0.367761

# %% [markdown]
# Create dataframe for different regressor y_pred values

# %%
df_y_pred = pd.DataFrame({'Actual':y_test,'lr_pred':lr_pred, 'dt_pred':dt_pred,'sv_pred':sv_pred,'rf_pred':rf_pred,'gb_pred':gb_pred, 'knn_pred':knn_pred, 'xgb_pred':xgb_pred})

# %%
df_y_pred.head()
# Out:
#            Actual       lr_pred       dt_pred      sv_pred       rf_pred  \
# 764    9095.06825   8924.407244  10550.640437  9548.501784  11495.341649
# 887    5272.17580   7116.295018   5243.041297  9493.253027   5405.166264
# 890   29330.98315  36909.013521  26871.091523  9648.297116  28516.004570
# 1293   9301.89355   9507.874691  10550.640437  9555.223014  10392.672181
# 259   33750.29180  27013.350008  34232.778608  9421.474560  34414.649939
#
#            gb_pred      knn_pred      xgb_pred
# 764   11001.128629   8690.432370  12452.023438
# 887    5840.174656   8102.826680   9811.813477
# 890   28001.980112  17125.185200  28388.507812
# 1293   9745.291602  11850.671280   8691.573242
# 259   33639.100981  15332.645516  34421.667969

# %%
sns.scatterplot(x=y_test, y=y_pred)
diagonal_x = np.linspace(0, 70000, 100)
diagonal_y = diagonal_x
plt.plot(diagonal_x, diagonal_y, color='red')
plt.xlim(0, 70000)
plt.ylim(0, 70000)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Scatter Plot of Actual vs Predicted Charges')
plt.show()

# %% [markdown]
# Building a predictive system

# %%
df_encoded.head()

X = df_encoded.drop('charges', axis=1)
y = df_encoded['charges']

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# Initialize and train the model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Collect user inputs
age = int(input("Please enter your age: "))
sex = int(input("Please enter your gender: (male:0 / female:1) "))
bmi = float(input("Please enter your bmi: "))
children = int(input("How many children do you have? (0-5): "))
smoker = int(input("Are you a smoker? (yes:1 / no:0) "))
region = int(input("Which region do you live? (southwest:0 / southeast:1 / northwest:2 / northeast:3) ")) 

# Create a DataFrame with the same column names as the training data
input_data = pd.DataFrame([[age, sex, bmi, children, smoker, region]], columns=['age', 'sex', 'bmi', 'children', 'smoker', 'region'])

# Predict the medical cost
input_pred = regressor.predict(input_data)
print("The predicted medical cost is: ", input_pred[0])
# Out:
# Please enter your age:  25
# Please enter your gender: (male:0 / female:1)  1
# Please enter your bmi:  43
# How many children do you have? (0-5):  0
# Are you a smoker? (yes:1 / no:0)  0
# Which region do you live? (southwest:0 / southeast:1 / northwest:2 / northeast:3)  3
# The predicted medical cost is:  8899.612679905791
